# %%
import xlwings as xw
import requests
# import json
import time
import openpyxl
from lxml import etree
from itertools import product

#pubmedから検索する部分
def detect(kensaku):
    query_set_1 = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term="
    query_set_2 = "&retmode=json"
    #組み合わせの取得: 6*5*5=150通り
    keylist = [list(v) for v in product(*kensaku)]
    #組み合わせからクエリを取得
    query = [query_set_1 + " (" + str(q[0]) + ") AND (" + str(q[1]) + ") AND (" + str(q[2]) + ") " + query_set_2 for q in keylist]
    #検索結果の返信
    response = []
    for res in query:
        response.append(requests.get(res))
        print(res)
#     print(query[0])
    #検索結果を返す
    return response, keylist

def keyword(ws):
    #キーワード数
    cnt = 3
    #キーワードボックス
    kensaku = [[], [], []]
    #キーワードの取得
    num = 2
    while ws["b"][num].value:
        kensaku[0].append(ws["b"][num].value)
        num+=1
    num = 2
    while ws["c"][num].value:
        kensaku[1].append(ws["c"][num].value)
        num+=1
    num = 2
    while ws["d"][num].value:
        kensaku[2].append(ws["d"][num].value)
        num+=1
    return kensaku

#論文数の取得・書き込み
def pm_cnt(response):
    #論文数
    cnt = [res.json()['esearchresult']['count'] for res in response]
    return cnt

def show(cnt, keylist, ws):
    i = 1
    for (c, k) in zip(cnt, keylist):
        ws.cell(row=15+i, column=7).value=i
        ws.cell(row=15+i, column=8).value=k[0]
        ws.cell(row=15+i, column=9).value=k[1]
        ws.cell(row=15+i, column=10).value=k[2]
        ws.cell(row=15+i, column=11).value=c
        i+=1
        

#リファレンス: https://openpyxl.readthedocs.io/en/stable/api/openpyxl.reader.excel.html#openpyxl.reader.excel.load_workbook
EXCEL_PATH = "C:\\Users\\makyua\\Desktop\\article-3\\article\\windows\\pubmed_3.xlsm"
#Excelファイルの読み込み
wb = openpyxl.load_workbook(EXCEL_PATH, keep_vba=True)
#Excelシートの読み込み
ws = wb["Season2"]

tm_st = time.time()

#検索キーワードの取得
kensaku = keyword(ws)

# #検索の実行、検索結果の格納
response, keylist = detect(kensaku)

# #検索結果から論文数の解析
cnt = pm_cnt(response)

#データを結合後、エクセルに反映
show(cnt, keylist, ws)

wb.save("C:\\Users\\makyua\\Desktop\\article-3\\article\\windows\\pubmed_3.xlsm")
# Out:
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (japanese) AND (cassava) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (american) AND (cassava) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (indian) AND (cassava) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (chinese) AND (cassava) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (spanish) AND (cassava) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (rice) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (rice) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (rice) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (rice) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (rice) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (hamburger) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (hamburger) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (hamburger) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (hamburger) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (hamburger) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (naan) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (naan) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (naan) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (naan) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (naan) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (baguette) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (baguette) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (baguette) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (baguette) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (baguette) AND (1000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (cassava) AND (1900) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (cassava) AND (1500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (cassava) AND (2000) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (cassava) AND (2500) &retmode=json
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=pubmed&term= (korean) AND (cassava) AND (1000) &retmode=json
